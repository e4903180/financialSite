# %%
import MySQLdb
import MySQLdb.cursors
import json
import pandas as pd
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
from tqdm import trange
from collections import defaultdict

class PopularNews():
    def __init__(self) -> None:
        db_config = json.load(open("../../db_config.json"))
        self._db = MySQLdb.connect(host = db_config["HOST"], user = db_config["USER"], passwd = db_config["PASSWD"],
                                    db = "financial", charset = "utf8", cursorclass = MySQLdb.cursors.DictCursor)
        self._cursor = self._db.cursor()

    def _init_table(self) -> None:
        query = "TRUNCATE TABLE popular_news"
        self._cursor.execute(query)
        self._db.commit()

    def _insert(self, ticker_id : str, news_id : str, interval : str) -> None:
        query = "INSERT INTO popular_news (ticker_id, news_id, time_interval) VALUES (%s, %s, %s)"
        param = (ticker_id, news_id, interval)

        self._cursor.execute(query, param)
        self._db.commit()

    def _get_news(self, interval : str = "3days") -> pd.DataFrame:
        if interval == "3days":
            start_date = (datetime.now() - timedelta(days = 3)).strftime("%Y-%m-%d")

        elif interval == "week":
            start_date = (datetime.now() - timedelta(days = 7)).strftime("%Y-%m-%d")

        elif interval == "month":
            start_date = (datetime.now() - relativedelta(months = 1)).strftime("%Y-%m-%d")

        query = "SELECT * FROM news WHERE date>=%s AND date<=%s"
        param = ("2023-02-01", "2023-02-07")

        self._cursor.execute(query, param)
        self._db.commit()

        result = pd.DataFrame.from_dict(self._cursor.fetchall())
        
        return result

    def _get_ticker_list(self) -> pd.DataFrame:
        query = "SELECT ID, stock_name FROM ticker_list WHERE LENGTH(stock_num)=4"

        self._cursor.execute(query,)
        self._db.commit()

        result = pd.DataFrame.from_dict(self._cursor.fetchall())

        stock_name = result["stock_name"].to_list()
        stock_name = [element[5:] for element in stock_name]

        result["stock_name"] = stock_name

        result = result.sort_values(by = ["stock_name"], ascending = False, key = lambda x: x.str.len())

        return result
    
    def _get_ticker_id(self, stock_num : str):
        query = "SELECT ID FROM ticker_list WHERE stock_num=%s"
        param = (stock_num,)

        self._cursor.execute(query, param)
        self._db.commit()

        result = pd.DataFrame.from_dict(self._cursor.fetchall())
        
        return result["ID"][0]

    def _handle_news(self, interval : str) -> None:
        result = defaultdict(list)

        news = self._get_news(interval = interval)
        ticker_list = self._get_ticker_list()

        for index_news in trange(len(news)):
            for index_ticker_list in range(len(ticker_list)):
                if ticker_list.iloc[index_ticker_list]["stock_name"] in news.iloc[index_news]["title"]:
                    if ticker_list.iloc[index_ticker_list]["stock_name"] == "冠軍":
                        if "隱形冠軍" in news.iloc[index_news]["title"]:
                            continue

                    result[ticker_list.iloc[index_ticker_list]["ID"]].append([news.iloc[index_news]["ID"], news.iloc[index_news]["title"], news.iloc[index_news]["link"]])
                    break
        
        result = {key : value for key, value in sorted(result.items(), key = lambda item : len(item[1]), reverse = True)}

        return result

    def run(self):
        # self._init_table()
        return self._handle_news(interval = "3days")
        # self._handle_news(interval = "week")
        # self._handle_news(interval = "month")

# %%
popular_news = PopularNews()

result = popular_news.run()
# Out:
# 100%|██████████| 1309/1309 [01:36<00:00, 13.59it/s]

# %%
ptr = 0
for num in result:
    if ptr == 11:
        break
    
    score = 0
    print(num)
    print(len(result[num]))
    for data in result[num]:
        print(data[1], data[2])
    
    print("====="*10)

    ptr += 1
# Out:
# 317
# 39
# 外資獲利了結賣超逾萬張 台積電早盤最低523元 https://money.udn.com//money/story/5607/6954791?from=edn_subcatelist_cate
# 紐約州共同退休基金減持台積電 兩大原因曝光 https://money.udn.com//money/story/5612/6954400?from=edn_subcatelist_cate
# 台積電跌10元 台股早盤跌逾百點 https://money.udn.com//money/story/5607/6952154?from=edn_subcatelist_cate
# 台積電股價開跌10元 早盤最低528元 https://money.udn.com//money/story/5607/6952330?from=edn_subcatelist_cate
# 台積電開盤下挫10元 台股跌逾百點暫失15500點 https://money.udn.com//money/story/5607/6952186?from=edn_subcatelist_cate
# 國研院半導體中心攜手台積電 導入7奈米晶片製作服務 https://money.udn.com//money/story/5612/6952767?from=edn_subcatelist_cate
# 國研院半導體中心導入台積電虛擬製程晶片設計訓練套件 https://money.udn.com//money/story/5612/6952670?from=edn_subcatelist_cate
# 接軌業界FinFET技術 半導體中心引入台積電訓練套件 https://money.udn.com//money/story/5612/6952662?from=edn_subcatelist_cate
# 台積電最後一盤爆7,194張成交量 收最低526元、市值滑落14兆 https://money.udn.com//money/story/5607/6953007?from=edn_subcatelist_cate
# 台積電重挫16元 台股回檔209.84點失守15400點 https://money.udn.com//money/story/5607/6952914?from=edn_subcatelist_cate
# 世界工廠遷徙潮：供應鏈版圖全球開花  台積電牽動全球半導體版圖 https://money.udn.com//money/story/5607/6948418?from=edn_subcatelist_cate
# 台積電先行 引爆IC設計比價效應 https://money.udn.com//money/story/5607/6948399?from=edn_subcatelist_cate
# 台積電何時複製2020年行情，再攻一波？ https://money.udn.com//money/story/5607/6947914?from=edn_subcatelist_cate
# 台積電平盤震盪 台股開盤小跌 https://money.udn.com//money/story/5607/6946282?from=edn_subcatelist_cate
# 蘋果妙回晶片美國製造 庫克自豪為台積電新廠最大客戶 https://money.udn.com//money/story/5612/6946700?from=edn_subcatelist_cate
# 教育責任擔起來 台積電推出大學 FinFET 專案 https://money.udn.com//money/story/5612/6947728?from=edn_subcatelist_cate
# 30歲扛下Gogoro台灣總經理，陸學森為何欽點他？牽成台積電合作有2大獨門溝通法 https://money.udn.com//money/story/5612/6947593?from=edn_subcatelist_cate
# 台積電：開放學界使用業界最強FinFET技術 https://money.udn.com//money/story/5612/6947380?from=edn_subcatelist_cate
# 台積電開放學界使用業界最成功的FinFET技術 https://money.udn.com//money/story/5612/6947259?from=edn_subcatelist_cate
# 台積電推大學FinFET專案 培育半導體晶片設計人才 https://money.udn.com//money/story/5612/6947264?from=edn_subcatelist_cate
# 培育半導體晶片設計人才 台積電推出大學 FinFET 專案 https://money.udn.com//money/story/5612/6947177?from=edn_subcatelist_cate
# 台積電供應商世創：矽晶圓需求仍強 終端市場可能趨緩 https://money.udn.com//money/story/5612/6947139?from=edn_subcatelist_cate
# 台積電尾盤助攻、台股由黑翻紅 小漲7.5點收15,602點 https://money.udn.com//money/story/5607/6947057?from=edn_subcatelist_cate
# 台積電拉抬指數尾盤翻紅 台股週漲4.48%連4紅 https://money.udn.com//money/story/5607/6947146?from=edn_subcatelist_cate
# 台積電勁揚10元 台股收漲175點站上15500點 https://money.udn.com//money/story/5607/6944567?from=edn_subcatelist_cate
# 為什麼台積電大漲，英特爾大跌？同樣面對產業逆風 兩大龍頭法說會後兩樣情的背後關鍵 https://money.udn.com//money/story/5612/6945449?from=edn_subcatelist_cate
# Fed升息1碼如預期、權值股穩軍心 台股早盤漲逾百點 台積電開漲8元 https://money.udn.com//money/story/5607/6943556?from=edn_subcatelist_cate
# 台積電掀市值14兆元保衛戰 聯電站上50元 https://money.udn.com//money/story/5607/6943729?from=edn_subcatelist_cate
# 台積電大漲12元  台股早盤開高勁揚百點 https://money.udn.com//money/story/5607/6943585?from=edn_subcatelist_cate
# 台積電領軍多頭、元宇宙族群漲停 台股漲175點收15,595點 https://money.udn.com//money/story/5607/6944357?from=edn_subcatelist_cate
# 台股早盤漲逾百點 台積電開盤上揚10元 https://money.udn.com//money/story/5607/6940884?from=edn_subcatelist_cate
# 台積電飆10元 電子股反攻 台股早盤漲百點 https://ctee.com.tw/news/stocks/799256.html
# 亞洲供應鏈市值百大企業2022年調查  台積電蟬聯冠軍 https://money.udn.com//money/story/5612/6941430?from=edn_subcatelist_cate
# 解封概念股強勢 台股上漲154點收15,420點 台積電收530元 https://money.udn.com//money/story/5607/6941683?from=edn_subcatelist_cate
# 力挺護國神山 新制勞退基金投資台股 三成重押台積電 https://money.udn.com//money/story/5607/6941115?from=edn_subcatelist_cate
# 台積電甩尾 台股收漲154點站上15400點 https://money.udn.com//money/story/5607/6941719?from=edn_subcatelist_cate
# 外資按讚台積電 目標價上看700元 盤中股價一度漲至533元 https://money.udn.com//money/story/5607/6941192?from=edn_subcatelist_cate
# 台股早盤開高百點站上15300點 台積電漲2% https://money.udn.com//money/story/5607/6940898?from=edn_subcatelist_cate
# 盤前分析／短期受FOMC會議影響 美元指數、新台幣匯率及台積電走勢為觀察指標 https://money.udn.com//money/story/5607/6940851?from=edn_subcatelist_cate
# ==================================================
# 349
# 24
# MSCI季度調整 創意納入機率高、宏碁慎防被移除 https://money.udn.com//money/story/5607/6954886?from=edn_subcatelist_cate
# MSCI成分股 創意有望入列 https://money.udn.com//money/story/5607/6956592?from=edn_subcatelist_cate
# 創意、譜瑞 四檔馬力強 https://money.udn.com//money/story/5739/6956534?from=edn_subcatelist_cate
# 鳴日號Q2創意拍台灣 2/9正式開賣 https://money.udn.com//money/story/5612/6954974?from=edn_subcatelist_cate
# MSCI 季度調整 法人看好創意將入列 https://money.udn.com//money/story/5607/6952370?from=edn_subcatelist_cate
# 創意1月業績20.87億元 創歷年同期新紀錄 https://money.udn.com//money/story/5612/6953693?from=edn_subcatelist_cate
# 創意1月營收20.87億元 月減逾三成 https://money.udn.com//money/story/5612/6953187?from=edn_subcatelist_cate
# 創意1月營收月減33% 全年估雙位數增幅 https://money.udn.com//money/story/5612/6953103?from=edn_subcatelist_cate
# 創意、貿聯 押長天期 https://money.udn.com//money/story/5739/6953970?from=edn_subcatelist_cate
# 創意拚全年獲利成長 https://money.udn.com//money/story/5710/6948030?from=edn_subcatelist_cate
# 創意看好企業級SSD應用 添動能 https://money.udn.com//money/story/5710/6948033?from=edn_subcatelist_cate
# 創意、瑞昱 押中長天期 https://money.udn.com//money/story/5739/6948003?from=edn_subcatelist_cate
# 面對美對陸晶片禁令 創意總座:更加小心因應 https://www.moneydj.com/KMDJ/News/NewsViewer.aspx?a=be6bd90b-eefd-4f5e-9eb8-991a08e95756
# 創意迎最旺首季，全年再成長雙位數 https://www.moneydj.com/KMDJ/News/NewsViewer.aspx?a=75b35a20-f869-4d5b-91e5-294d4bcae535
# 法說下午登場 發哥創意股價兩樣情 https://money.udn.com//money/story/5607/6946541?from=edn_subcatelist_cate
# 創意：對今年展望還是非常有信心 營收有望雙位數成長 https://money.udn.com//money/story/5612/6947604?from=edn_subcatelist_cate
# 創意總座喊話有信心 今年營收維持雙位數成長 https://money.udn.com//money/story/5612/6947327?from=edn_subcatelist_cate
# 創意今年營收看增2位數 每股純益可望續創新高 https://money.udn.com//money/story/5612/6947314?from=edn_subcatelist_cate
# 創意看Q1估季減雙位數 但仍有望優於去年Q3 https://money.udn.com//money/story/5612/6947176?from=edn_subcatelist_cate
# AI、HPC雙動能撐腰 創意亮燈漲停飆上歷史天價 https://money.udn.com//money/story/5607/6944203?from=edn_subcatelist_cate
# 創意去年EPS逾27元 Q4為首度單季賺逾一股本 https://money.udn.com//money/story/5612/6945393?from=edn_subcatelist_cate
# 創意去年每股賺27.69元創新高  擬配息14元 https://money.udn.com//money/story/5612/6945312?from=edn_subcatelist_cate
# 今日最夯股／創意創天價，法人籌碼穩定性高，今年業績有多旺？ https://money.udn.com//money/story/5607/6945196?from=edn_subcatelist_cate
# 創意去年EPS 27.69元 https://money.udn.com//money/story/5710/6945501?from=edn_subcatelist_cate
# ==================================================
# 315
# 22
# 聯電1月營收月減6.4% 法人估今年EPS約5元 https://money.udn.com//money/story/5612/6954718?from=edn_subcatelist_cate
# 聯電元月營收探15月低點 https://money.udn.com//money/story/5612/6954278?from=edn_subcatelist_cate
# 法人看後市 聯電機會、挑戰兼具 https://money.udn.com//money/story/5612/6954293?from=edn_subcatelist_cate
# 聯電今年EPS 法人喊5元 https://money.udn.com//money/story/5710/6956597?from=edn_subcatelist_cate
# 聯電營收黯淡 連五個月下滑 https://ctee.com.tw/news/tech/802871.html
# 工作天數減少 聯電1月營收月減6.5%、下探近15個月來低點 https://money.udn.com//money/story/5612/6953082?from=edn_subcatelist_cate
# 聯電1月合併營收195.9億元 月減6.48%、年減4.31% https://money.udn.com//money/story/5612/6953262?from=edn_subcatelist_cate
# 外資上週買超1195億元  加碼聯電17.62萬張最多 https://money.udn.com//money/story/5612/6953259?from=edn_subcatelist_cate
# 聯電1月營收跌破200億元 創15個月低 https://money.udn.com//money/story/5612/6953177?from=edn_subcatelist_cate
# 聯電1月營收195.9億元  呈現雙減 https://money.udn.com//money/story/5612/6953131?from=edn_subcatelist_cate
# 外資狂買為哪樁？聯電元月營收創1年多來新低 https://money.udn.com//money/story/5607/6953519?from=edn_subcatelist_cate
# 聯電1月營收近15月低點 仍創同期次高 https://ctee.com.tw/news/tech/802492.html
# 外資連14買續布局晶圓雙雄 加碼聯電1.65萬張居冠 https://money.udn.com//money/story/5607/6948042?from=edn_subcatelist_cate
# 外資連13買續布局晶圓雙雄 加碼聯電3.6萬張居冠 https://money.udn.com//money/story/5607/6945158?from=edn_subcatelist_cate
# 聯電增員工產假陪產假 協助舒解少子化問題 https://money.udn.com//money/story/5612/6943930?from=edn_subcatelist_cate
# 外資今年來狂買超逾30萬張 聯電收復50元創7個多月高 https://money.udn.com//money/story/5607/6943883?from=edn_subcatelist_cate
# 期交所公告 調整聯電等24檔股票期貨及1檔股票選擇權契約保證金 https://money.udn.com//money/story/5607/6943640?from=edn_subcatelist_cate
# 外資買超225.37億元 聯電續蟬聯買超個股冠軍 https://money.udn.com//money/story/5607/6945032?from=edn_subcatelist_cate
# 聯電攜手Cadence開發3D-IC解決方案 https://money.udn.com//money/story/5612/6942055?from=edn_subcatelist_cate
# 聯電、益華電腦攜手 開發3D-IC混合鍵合參考流程 https://money.udn.com//money/story/5612/6942084?from=edn_subcatelist_cate
# 聯電與Cadence共同開發3D-IC混合鍵合參考流程 https://money.udn.com//money/story/5612/6942639?from=edn_subcatelist_cate
# 聯電攜手益華 推出3D-IC混合鍵合參考流程 https://money.udn.com//money/story/5612/6941973?from=edn_subcatelist_cate
# ==================================================
# 699
# 21
# 蘋果連4年居全球半導體最大買家 鴻海第10名 https://money.udn.com//money/story/5612/6954835?from=edn_subcatelist_cate
# 解僱前技術長魏國章訴訟 鴻海：依法辦理、靜待判決 https://money.udn.com//money/story/5612/6954659?from=edn_subcatelist_cate
# 鴻海被指稱逼退前技術長 新北：有調解卻調整未成 https://money.udn.com//money/story/5612/6956184?from=edn_subcatelist_cate
# 蘋果連4年居半導體最大買家 鴻海第10名 https://ctee.com.tw/news/tech/803222.html
# 鴻海遭指逼退前技術長 公司回應了 https://money.udn.com//money/story/5612/6954877?from=edn_subcatelist_cate
# 6,604億！鴻海營收創最旺1月 https://money.udn.com//money/story/5612/6951810?from=edn_subcatelist_cate
# 不受立訊搶單干擾 鴻海居高階iPhone組裝一哥 https://money.udn.com//money/story/5612/6951822?from=edn_subcatelist_cate
# 鴻海1月營收6604億元創同期新高 月增4.9%、年增48.1% https://money.udn.com//money/story/5612/6951171?from=edn_subcatelist_cate
# 鴻海1月營收創同期新高 年增近5成 https://money.udn.com//money/story/5612/6951290?from=edn_subcatelist_cate
# 蘋果證實本季iPhone供應好轉 鴻海沾光 https://money.udn.com//money/story/5612/6947366?from=edn_subcatelist_cate
# 三年推出五款原型車，靠電動車新進展，鴻海股價回100元只是開始？ https://money.udn.com//money/story/5612/6945828?from=edn_subcatelist_cate
# 更安全、更續航　電動車殺手級新應用，比爾蓋茲與鴻海都爭搶 https://money.udn.com//money/story/5612/6945689?from=edn_subcatelist_cate
# 劉揚偉透露鴻海規劃赴歐 設電動車零件廠 https://money.udn.com//money/story/5612/6943166?from=edn_subcatelist_cate
# 劉揚偉：關潤加入鴻海 有利電動車產業發展 https://money.udn.com//money/story/5612/6943168?from=edn_subcatelist_cate
# 影／鴻海新春團拜 劉揚偉曝EV新進展，3月親赴美訪客戶 https://money.udn.com//money/story/5612/6942692?from=edn_subcatelist_cate
# 劉揚偉：鴻海大陸生產恢復正常 延攬關潤對台灣EV有幫助 https://money.udn.com//money/story/5612/6941240?from=edn_subcatelist_cate
# 鴻海董事長劉揚偉：上半年景氣蠻挑戰 將會看到一些影響 https://money.udn.com//money/story/5612/6941134?from=edn_subcatelist_cate
# 影／鴻海開工新春團拜　劉揚偉：下半年景氣可能翻轉 https://money.udn.com//money/story/5612/6941332?from=edn_subcatelist_cate
# 鴻海在歐洲布局電動車零配件 劉揚偉最快3月赴美 https://money.udn.com//money/story/5612/6941214?from=edn_subcatelist_cate
# 鴻海劉揚偉：今年景氣有挑戰  下半年拚反轉 https://money.udn.com//money/story/5612/6941132?from=edn_subcatelist_cate
# 鴻海收復百元 最後一盤爆6,106張成交量 https://money.udn.com//money/story/5607/6942017?from=edn_subcatelist_cate
# ==================================================
# 527
# 17
# 中華電：三星S23旗艦預購額滿 頂規版占比7成 https://money.udn.com//money/story/5612/6956406?from=edn_subcatelist_cate
# 三星Galaxy S23 中華電預購額滿 最愛墨竹綠、夜櫻紫 https://money.udn.com//money/story/5612/6956321?from=edn_subcatelist_cate
# 中華電宣布5G資費有感升級方案 免費市話大加碼 https://money.udn.com//money/story/5612/6953968?from=edn_subcatelist_cate
# 中華電5G優惠升級 加碼送市話、流量轉贈、無線上網 https://money.udn.com//money/story/5612/6953899?from=edn_subcatelist_cate
# 因應台灣燈會上網需求 中華電布建200座高效基地台 https://money.udn.com//money/story/5612/6949562?from=edn_subcatelist_cate
# 中華電信核心業務成長 5G固網動能強勁 https://money.udn.com//money/story/5612/6945217?from=edn_subcatelist_cate
# 中華電上季犀利 超越財測 https://money.udn.com//money/story/5710/6945452?from=edn_subcatelist_cate
# 中華電串流影音業務發威 https://money.udn.com//money/story/5710/6942822?from=edn_subcatelist_cate
# 中華電去年第四季每股賺1.09元 全年EPS 4.71元 https://money.udn.com//money/story/5612/6944770?from=edn_subcatelist_cate
# 鴻海、中華電都有份！智慧管理AI巡田水   科技正在改變農業 https://money.udn.com//money/story/5612/6942899?from=edn_subcatelist_cate
# 中華電估今年營收增/獲利微減，EPS 4.45-4.65元 https://www.moneydj.com/KMDJ/News/NewsViewer.aspx?a=32825e5e-7b85-4395-a991-2abc8c7255df
# 中華電信MOD、Hami Video雙平台《牛車來去》居冠 https://money.udn.com//money/story/5612/6942539?from=edn_subcatelist_cate
# 中華電信影視雙平台 春節收視開紅盤 https://money.udn.com//money/story/5612/6942387?from=edn_subcatelist_cate
# 中華電信5G網速評測蟬聯第一  遠傳緊追在後 https://money.udn.com//money/story/5612/6942277?from=edn_subcatelist_cate
# 中華電信連續5年獲最佳行動涵蓋、台灣5G網速第一名 https://money.udn.com//money/story/5612/6941313?from=edn_subcatelist_cate
# 中華電財測 今年EPS上看4.65元 https://money.udn.com//money/story/11162/6940501?from=edn_subcatelist_cate
# 中華電信激勵員工 每人發1.5萬元 https://money.udn.com//money/story/11162/6940506?from=edn_subcatelist_cate
# ==================================================
# 335
# 16
# 台積、聯發科 四檔紅火 https://money.udn.com//money/story/5739/6951554?from=edn_subcatelist_cate
# 聯發科去年大賺逾七股本 https://money.udn.com//money/story/5612/6948324?from=edn_subcatelist_cate
# 聯發科台新2C購01 帶勁 https://money.udn.com//money/story/5739/6949947?from=edn_subcatelist_cate
# 聯發科看營運 Q2好轉 https://money.udn.com//money/story/5612/6948323?from=edn_subcatelist_cate
# 台積、聯發科 認購火 https://money.udn.com//money/story/5739/6948001?from=edn_subcatelist_cate
# 聯發科Q2營運有望好轉；法說會重點一次看 https://www.moneydj.com/KMDJ/News/NewsViewer.aspx?a=9b42049a-0c14-46a1-8ca6-3dab95e1a22c
# 聯發科去年每股賺74.59元，創歷史新高 https://www.moneydj.com/KMDJ/News/NewsViewer.aspx?a=5fc77d1b-e895-4309-9745-6009486deefa
# 聯發科：本季有望為營運低點 Q2逐步好轉 https://money.udn.com//money/story/5612/6947649?from=edn_subcatelist_cate
# 聯發科去年Q4純益下探兩年新低 但全年仍大賺7個股本 https://money.udn.com//money/story/5612/6947348?from=edn_subcatelist_cate
# 聯發科去年每股賺74.59元創高 估今年首季營收減逾6% https://money.udn.com//money/story/5612/6947645?from=edn_subcatelist_cate
# 聯發科去年又賺進超過七個股本 獲利再創新高 https://money.udn.com//money/story/5612/6947376?from=edn_subcatelist_cate
# 高通示警手機庫存調整至上半年 聯發科首季營收恐降 https://money.udn.com//money/story/5612/6946353?from=edn_subcatelist_cate
# 聯發科去年第4季獲利下探近2年新低 https://money.udn.com//money/story/5612/6947907?from=edn_subcatelist_cate
# 整理包／聯發科法說會 六大重點一次看 https://money.udn.com//money/story/5612/6947803?from=edn_subcatelist_cate
# 聯發科明日法說登場，觀察四大重點 https://www.moneydj.com/KMDJ/News/NewsViewer.aspx?a=d9fc025b-b808-4791-ae49-0538c828c159
# 聯發科首度執行員工持股計畫  當年電子業分紅盛況將再起？ https://money.udn.com//money/story/11162/6945017?from=edn_subcatelist_cate
# ==================================================
# 402
# 15
# 宏碁遊戲元月營收創新高 增幅稱霸宏碁「小虎隊」 https://money.udn.com//money/story/5612/6956204?from=edn_subcatelist_cate
# 宏碁「小虎隊」 業績亮眼 https://money.udn.com//money/story/5710/6956561?from=edn_subcatelist_cate
# 從花錢單位變「賺錢部門」 宏碁靠節能3年業績翻倍 https://money.udn.com//money/story/5612/6950965?from=edn_subcatelist_cate
# 宏碁：營運逐季增長 https://money.udn.com//money/story/5710/6948028?from=edn_subcatelist_cate
# 宏碁台灣區上半年看保守、下半年料轉正 https://www.moneydj.com/KMDJ/News/NewsViewer.aspx?a=ff8788b9-21d4-47be-afb4-5f1a69a9b1c4
# 宏碁：走過去年旺季不旺 台灣區今年力拼逐季成長 https://money.udn.com//money/story/5612/6947859?from=edn_subcatelist_cate
# 宏碁台灣區今年營運審慎樂觀 下半年PC將超過去年同期 https://money.udn.com//money/story/5612/6947846?from=edn_subcatelist_cate
# 宏碁：已見消費信心回溫 台灣區今年業績拚逐季成長 https://money.udn.com//money/story/5612/6947763?from=edn_subcatelist_cate
# PC產業資深戰將蘭奇逝世 宏碁：感到遺憾 https://money.udn.com//money/story/5612/6945621?from=edn_subcatelist_cate
# 宏碁義大利籍前執行長蘭奇過世  享壽68歲 https://money.udn.com//money/story/5612/6945616?from=edn_subcatelist_cate
# 宏碁叛將蘭奇過世！縱橫兩岸PC界40年  留下傳奇人生 https://money.udn.com//money/story/5612/6945336?from=edn_subcatelist_cate
# 縱橫PC業 宏碁叛將蘭奇病逝 https://money.udn.com//money/story/11162/6945796?from=edn_subcatelist_cate
# 宏碁新NB攻教育商機 https://money.udn.com//money/story/5710/6942846?from=edn_subcatelist_cate
# 宏碁傳攜手超微 拓顯卡業務 https://money.udn.com//money/story/5710/6942850?from=edn_subcatelist_cate
# 宏碁強攻教育商機 推出新款Chromebook筆電 https://money.udn.com//money/story/5612/6940952?from=edn_subcatelist_cate
# ==================================================
# 265
# 15
# 三星S23上市 銷售看增20% https://money.udn.com//money/story/11162/6954290?from=edn_subcatelist_cate
# 三星手機S23登台 貴2～3千 https://ctee.com.tw/news/tech/802981.html
# 三星電機積極開拓ABF載板應用 今年看好伺服器車用需求 https://money.udn.com//money/story/5612/6952890?from=edn_subcatelist_cate
# 三星Galaxy S23預購開跑！零元購機、電信資費一次看 https://money.udn.com//money/story/5612/6954101?from=edn_subcatelist_cate
# 三星S23旗艦系列登台 銷量拚增2成 https://money.udn.com//money/story/5612/6953831?from=edn_subcatelist_cate
# 三星看旺高階機 台灣市場目標銷量年增二成 https://money.udn.com//money/story/5612/6953830?from=edn_subcatelist_cate
# 三星全新旗艦機Galaxy S23全系列 燦坤明中午開放預購 https://money.udn.com//money/story/5612/6953788?from=edn_subcatelist_cate
# S23系列大漲 台灣三星仍拚銷量年增20％ https://ctee.com.tw/news/tech/802818.html
# 韓媒：三星晶片部門 上半年恐虧10億美元 https://ctee.com.tw/news/tech/802560.html
# 手機界單眼最新力作！三星Galaxy S23旗艦系列強勢登場 https://money.udn.com//money/story/11162/6943359?from=edn_subcatelist_cate
# 三星：頂級產品成長力道強 https://money.udn.com//money/story/11162/6943092?from=edn_subcatelist_cate
# 三星：經濟逆風對高階手機影響小於整體市場 https://www.moneydj.com/KMDJ/News/NewsViewer.aspx?a=c76656f4-5190-4cb7-a669-4a8ee6518adf
# 新旗艦力抗經濟頹勢 三星：看好高階客層撐盤 https://money.udn.com//money/story/5612/6943735?from=edn_subcatelist_cate
# 三星S23旗艦系列亮相 主打夜幕攝影3亮點 https://money.udn.com//money/story/5612/6943587?from=edn_subcatelist_cate
# 三星示警 上半年依然艱困 https://money.udn.com//money/story/5612/6940484?from=edn_subcatelist_cate
# ==================================================
# 471
# 14
# 大立光1月營收為8個月低；2月展望仍保守 https://www.moneydj.com/KMDJ/News/NewsViewer.aspx?a=7949fb4c-91ca-4d95-92ab-91bec572f4c5
# 鴻海創最旺1月、股價衝上季線 大立光則受營收探低拖累 https://money.udn.com//money/story/5607/6952237?from=edn_subcatelist_cate
# 大立光公布元月營收後 法人將評等維持中立 https://money.udn.com//money/story/5607/6952396?from=edn_subcatelist_cate
# 出貨淡季到 法人維持大立光中立投資建議 https://money.udn.com//money/story/5607/6954070?from=edn_subcatelist_cate
# 大立光元月營收 探近八月低點 https://money.udn.com//money/story/5612/6951812?from=edn_subcatelist_cate
# 大立光旗艦機鏡頭出貨 跌破一成 https://money.udn.com//money/story/5612/6951816?from=edn_subcatelist_cate
# 大立光元月營收32.6億元、月減18% 為八個月來低點 https://money.udn.com//money/story/5612/6950617?from=edn_subcatelist_cate
# 手機需求不旺 大立光1月營收雙降2月恐更差 https://money.udn.com//money/story/5612/6950743?from=edn_subcatelist_cate
# 信驊狠甩大立光 榮登股王寶座？解讀老董林鴻明的三高策略 https://money.udn.com//money/story/5607/6948226?from=edn_subcatelist_cate
# 信驊重登股王 超車大立光 https://money.udn.com//money/story/5607/6945948?from=edn_subcatelist_cate
# 不怕蘋果光失色 台積電、大立光不跌反漲但鴻海失守百元 https://money.udn.com//money/story/5607/6947156?from=edn_subcatelist_cate
# 信驊大漲115元 超車大立光登股王 https://money.udn.com//money/story/5607/6944467?from=edn_subcatelist_cate
# 信驊大漲160元衝上2320元 超越大立光登股王 https://money.udn.com//money/story/5607/6943990?from=edn_subcatelist_cate
# 三星推旗艦機 大立光上鏡 https://money.udn.com//money/story/11162/6943095?from=edn_subcatelist_cate
# ==================================================
# 16
# 13
# 市場派3月召集股臨會改選　泰山公司派今提假處分反制 https://money.udn.com//money/story/5612/6956451?from=edn_subcatelist_cate
# 泰山阻市場派開股臨會 提假處分聲請 https://money.udn.com//money/story/5612/6956370?from=edn_subcatelist_cate
# 泰山公司派出招 阻止股臨會 https://money.udn.com//money/story/10871/6956881?from=edn_subcatelist_cate
# 泰山發言人申報轉讓手上所有持股 稱是個人理財規劃 https://money.udn.com//money/story/5612/6947925?from=edn_subcatelist_cate
# 泰山公告3月16日開股臨會 公司：⾮依程序上傳 將循司法途徑釐清 https://money.udn.com//money/story/5612/6945535?from=edn_subcatelist_cate
# 泰山公司派稱陳敏薰缺乏獨立性 龍邦：無法苟同 https://money.udn.com//money/story/5612/6945344?from=edn_subcatelist_cate
# 泰山擬解除陳敏薰職務 龍邦痛批公然蔑視獨董職權 https://money.udn.com//money/story/5612/6945292?from=edn_subcatelist_cate
# 泰山痛批陳敏薰背叛 龍邦：勿以旁門左道拖延股臨會 https://money.udn.com//money/story/5612/6945262?from=edn_subcatelist_cate
# 泰山3/16召開股臨會 https://money.udn.com//money/story/10871/6945802?from=edn_subcatelist_cate
# 泰山股臨會下月登場 經營權決戰關鍵日 https://money.udn.com//money/story/5612/6944957?from=edn_subcatelist_cate
# 泰山董事詹皓鈞：陳敏薰已缺乏獨立性 考慮提起解任訴訟 https://money.udn.com//money/story/5612/6944800?from=edn_subcatelist_cate
# 泰山公司派：陳敏薰已缺乏獨立性 籲自行辭職 https://money.udn.com//money/story/5612/6945025?from=edn_subcatelist_cate
# 經營權之爭未落幕　泰山：考慮解任陳敏薰獨董職務 https://money.udn.com//money/story/5612/6944684?from=edn_subcatelist_cate
# ==================================================
# 534
# 9
# 鴻海、宏達電登入 元宇宙迎來神隊友 https://money.udn.com//money/story/5612/6956645?from=edn_subcatelist_cate
# 宏達電1月營收2.15億元 月減58.7%、年減40.2% https://money.udn.com//money/story/5612/6953353?from=edn_subcatelist_cate
# 宏達電1月營收探掛牌次低 王雪紅受邀MWC演講 https://money.udn.com//money/story/5612/6953651?from=edn_subcatelist_cate
# 宏達電元月營收2.1億元 月減58.7%、業績雙率雙降 https://money.udn.com//money/story/5612/6953753?from=edn_subcatelist_cate
# 最牛一輪／宏達電靚 群益26有戲 https://money.udn.com//money/story/5739/6953961?from=edn_subcatelist_cate
# 宏達電1月營收雙減至2.15億 探次低 https://ctee.com.tw/news/tech/802635.html
# 宏達電、威盛 認購俏 https://money.udn.com//money/story/5739/6945366?from=edn_subcatelist_cate
# Meta盤後漲近20% 宏達電漲停領軍、4檔集團股同飆漲停 https://money.udn.com//money/story/5607/6943608?from=edn_subcatelist_cate
# 台股力守15500點 台積電聚人氣、宏達電攻漲停 https://money.udn.com//money/story/5607/6943771?from=edn_subcatelist_cate
# ==================================================
