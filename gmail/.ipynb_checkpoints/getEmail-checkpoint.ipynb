# %%
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
import pickle
import os.path
import base64
import email
from tqdm import trange
from bs4 import BeautifulSoup

# %%
# Define the SCOPES. If modifying it, delete the token.pickle file.
SCOPES = ['https://www.googleapis.com/auth/gmail.readonly']

# %%
def getEmails():
    # Variable creds will store the user access token.
    # If no valid token found, we will create one.
    creds = None
  
    # The file token.pickle contains the user access token.
    # Check if it exists
    if os.path.exists('token.pickle'):
  
        # Read the token from the file and store it in the variable creds
        with open('token.pickle', 'rb') as token:
            creds = pickle.load(token)
  
    # If credentials are not available or are invalid, ask the user to log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file('credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
  
        # Save the access token in token.pickle file for the next run
        with open('token.pickle', 'wb') as token:
            pickle.dump(creds, token)
  
    # Connect to the Gmail API
    service = build('gmail', 'v1', credentials=creds)
  
    # request a list of all the messages
    result = service.users().messages().list(userId='me').execute()
  
    # We can also pass maxResults to get any number of emails. Like this:
    # result = service.users().messages().list(maxResults=200, userId='me').execute()
    messages = result.get('messages')
  
    # messages is a list of dictionaries where each dictionary contains a message id.
  
    # iterate through all the messages
    for i in trange(len(messages)):
        # Get the message from its id
        txt = service.users().messages().get(userId = 'me', id = messages[i]['id']).execute()
        print(txt)
  
        # Use try-except to avoid any Errors
        try:
            # Get value of 'payload' from dictionary 'txt'
            payload = txt['payload']
            headers = payload['headers']
  
            # Look for Subject and Sender Email in the headers
            for d in headers:
                if d['name'] == 'Subject':
                    subject = d['value']
                if d['name'] == 'From':
                    sender = d['value']
  
            # The Body of the message is in Encrypted format. So, we have to decode it.
            # Get the data and decode it with base 64 decoder.
            parts = payload.get('parts')[0]
            data = parts['body']['data']
            data = data.replace("-","+").replace("_","/")
            decoded_data = base64.b64decode(data)
  
            # Now, the data obtained is in lxml. So, we will parse 
            # it with BeautifulSoup library
            soup = BeautifulSoup(decoded_data , "lxml")
            body = soup.body()
  
            # Printing the subject, sender's email and message
            print("Subject: ", subject)
            print("From: ", sender)
            print("Message: ", body)
            print('\n')
        except:
            pass

# %%
getEmails()
# Out:
#   1%|▍                                          | 1/100 [00:00<00:30,  3.27it/s]
# {'id': '17f631a08e8f9ee0', 'threadId': '17f631a08e8f9ee0', 'labelIds': ['UNREAD', 'CATEGORY_UPDATES', 'INBOX'], 'snippet': '最新氣象消息請參考www.cwb.gov.tw 07fW26073 中央氣象局大雨特報： １１１年３月７日１４時２５分發布 大雨特報： 鋒面影響，今（７）日基隆北海岸有局部大雨發生的機率，請注意。', 'payload': {'partId': '', 'mimeType': 'text/html', 'filename': '', 'headers': [{'name': 'Delivered-To', 'value': 'leo4707@gmail.com'}, {'name': 'Received', 'value': 'by 2002:adf:f94d:0:0:0:0:0 with SMTP id q13csp1128545wrr;        Sun, 6 Mar 2022 22:38:45 -0800 (PST)'}, {'name': 'X-Google-Smtp-Source', 'value': 'ABdhPJzC0RFTBEmrT7C1kQnp5VTkirfsec5tKoHRreXrbn1afkL0s76mF0d3+ZZFKw7Nrb0n39tQ'}, {'name': 'X-Received', 'value': 'by 2002:a63:2314:0:b0:370:5429:84ed with SMTP id j20-20020a632314000000b00370542984edmr8605707pgj.469.1646635125008;        Sun, 06 Mar 2022 22:38:45 -0800 (PST)'}, {'name': 'ARC-Seal', 'value': 'i=1; a=rsa-sha256; t=1
=='}, {'name': 'ARC-Message-Signature', 'value': 'i=1; a=rsa-sha256; c=relaxed/relaxed; d=google.com; s=arc-20160816;        h=message-id:content-transfer-encoding:subject:date:to:from         :mime-version:feedback-id:dkim-signature;        bh=WRSv4N1BXGhoRuF3X7CcAknIaQ6tte/gYdIxLb89ltU=;        b=mvIJ0i45f0KR4eyyDuIi3XnZ7xnhwR22oWeb25BN/HBTKA0+KhG9oFVyUsjuW9jcHP         dSpL12VgKdDQQUHPXpZFbJdHpBF9ZZU35W/9EqeYjU6DQi1CWmmd8YhCIitSqXsy4jCm         bz5rAJEfyv6fGCjwkaALz9rjZxuhLReqZt3E2YyffeNjyDkXu2xR8nrmagGBtK9in4Bd         G7Yi8YqrjD7KS1MQd0r+RdcqMOmbFNuNNjOVtECFw8xGYVqK2LIk39Wiw2gZMJI2VW0Y         56Ad8hV04fbXbKIec1saNKd4xH801nKfl7psnftPIFiXF4B/MxonELtiUVVulo3GBZgR         vO3w=='}, {'name': 'ARC-Authentication-Results', 'value': 'i=1; mx.google.com;       dkim=pass header.i=@maillist.codeproject.com header.s=mail header.b=omfcyRfc;       spf=pass (google.com: domain of mailout@maillist.codeproject.com designates 76.74.234.204 as permitted sender) smtp.mailfrom=mailout@maillist.codeproject.com;       dmarc=pass (p=QUARANTINE sp=QUARANTINE dis=NONE) header.from=codeproject.com'}, {'name': 'Return-Path', 'value': '<mailout@maillist.codeproject.com>'}, {'name': 'Received', 'value': 'from mail.maillist.codeproject.com (mail.maillist.codeproject.com. [76.74.234.204])        by mx.google.com with ESMTP id g11-20020a0cd7cb000000b004325e6b1858si4268934qvj.220.2022.03.06.22.34.18        for <leo4707@gmail.com>;        Sun, 06 Mar 2022 22:34:18 -0800 (PST)'}, {'name': 'Received-SPF', 'value': 'pass (google.com: domain of mailout@maillist.codeproject.com designates 76.74.234.204 as permitted sender) client-ip=76.74.234.204;'}, {'name': 'Authentication-Results', 'value': 'mx.google.com;       dkim=pass header.i=@maillist.codeproject.com header.s=mail header.b=omfcyRfc;       spf=pass (google.com: domain of mailout@maillist.codeproject.com designates 76.74.234.204 as permitted sender) smtp.mailfrom=mailout@maillist.codeproject.com;       dmarc=pass (p=QUARANTINE sp=QUARANTINE dis=NONE) header.from=codeproject.com'}, {'name': 'Received', 'value': 'from jobs01 (unknown [192.168.5.180]) by mail.maillist.codeproject.com (Postfix) with ESMTP id 9A22EC1ECD for <leo4707@gmail.com>; Mon,  7 Mar 2022 01:18:56 -0500 (EST)'}, {'name': 'DKIM-Signature', 'value': 'v=1; a=rsa-sha256; c=simple/simple; d=maillist.codeproject.com; s=mail; t=1646633936; bh=WRSv4N1BXGhoRuF3X7CcAknIaQ6tte/gYdIxLb89ltU=; h=MIME-Version:From:To:Date:Subject:Content-Type:\t Content-Transfer-Encoding:Message-Id; b=omfcyRfc7xUOlNWfI5bZqp8Xfb9zuJSc4JTreeGBktSOfvXvxFZvrYIpYP6PYxrem ...
#   4%|█▋                                         | 4/100 [00:01<00:30,  3.12it/s]
# {'id': '17f628bde4ec215e', 'threadId': '17f628bde4ec215e', 'labelIds': ['UNREAD', 'CATEGORY_UPDATES', 'INBOX'], 'snippet': '立即領取，優惠期限至 03/20 領取 1 趟 200 元 優惠 優惠已經存入您的 Uber App 帳號，請記得在 03 月 20 日 前完成首趟 Uber 行程，即享有新用戶優惠，體驗最便捷的叫車服務。 現在就下載 Uber App 搭乘 【優惠注意事項】 所有行程僅透過 Uber 網際網路系統預定，由合作計程車隊派遣車輛。 叫車服務優惠適用於北北基、桃園、新竹、台中、彰化、台南、高雄，本活動及', 'payload': {'partId': '', 'mimeType': 'text/html', 'filename': '', 'headers': [{'name': 'Delivered-To', 'value': 'leo4707@gmail.com'}, {'name': 'Received', 'value': 'by 2002:adf:f94d:0:0:0:0:0 with SMTP id q13csp1068013wrr;        Sun, 6 Mar 2022 20:03:33 -0800 (PST)'}, {'name': 'X-Google-Smtp-Source', 'value': 'ABdhP
='}, {'name': 'ARC-Authentication-Results', 'value': 'i=1; mx.google.com;       spf=pass (google.com: domain of wwwadm@emsg1.cwb.gov.tw designates 163.29.179.58 as permitted sender) smtp.mailfrom=wwwadm@emsg1.cwb.gov.tw'}, {'name': 'Return-Path', 'value': '<wwwadm@emsg1.cwb.gov.tw>'}, {'name': 'Received', 'value': 'from emsg1.cwb.gov.tw (emsg1.cwb.gov.tw. [163.29.179.58])        by mx.google.com with ESMTPS id e9-20020a631e09000000b00372f2ba860esi11678368pge.413.2022.03.06.19.59.21        (version=TLS1_2 cipher=ECDHE-ECDSA-AES128-GCM-SHA256 bits=128/128);        Sun, 06 Mar 2022 19:59:22 -0800 (PST)'}, {'name': 'Received-SPF', 'value': 'pass (google.com: domain of wwwadm@emsg1.cwb.gov.tw designates 163.29.179.58 as permitted sender) client-ip=163.29.179.58;'}, {'name': 'Authentication-Results', 'value': 'mx.google.com;       spf=pass (google.com: domain of wwwadm@emsg1.cwb.gov.tw designates 163.29.179.58 as permitted sender) smtp.mailfrom=wwwadm@emsg1.cwb.gov.tw'}, {'name': 'Received', 'value': 'by emsg1.cwb.gov.tw (Postfix, from userid 1040) id 61CAC6DBD8; Mon,  7 Mar 2022 11:53:43 +0800 (CST)'}, {'name': 'To', 'value': '"交通部中央氣象局" <eservice@cwb.gov.tw>'}, {'name': 'Subject', 'value': '中央氣象局低溫特報'}, {'name': 'From', 'value': '"交通部中央氣象局" <eservice@cwb.gov.tw>'}, {'name': 'MIME-Version', 'value': '1.0'}, {'name': 'Content-Type', 'value': 'text/html; charset="utf-8"'}, {'name': 'Message-Id', 'value': '<20220307035343.61CAC6DBD8@emsg1.cwb.gov.tw>'}, {'name': 'Date', 'value': 'Mon,  7 Mar 2022 11:53:43 +0800 (CST)'}], 'body': {'size': 5082, 'data': 'DQo8aHRtbD4NCjxoZWFkPg0KPG1ldGEgaHR0cC1lcXVpdj0iQ29udGVudC1UeXBlIiBjb250ZW50PSJ0ZXh0L2h0bWw7IGNoYXJzZXQ9dXRmLTgiPg0KPG1ldGEgbmFtZT0iY292ZXJhZ2UudC5taW4iIGNvbnRlbnQ9IjIwMjItMD ...
#   6%|██▌                                        | 6/100 [00:01<00:29,  3.19it/s]
# {'id': '17f626eafcfdf43f', 'threadId': '17f626eafcfdf43f', 'labelIds': ['UNREAD', 'CATEGORY_PERSONAL', 'INBOX'], 'snippet': '英特爾台灣(Intel Taiwan)今年度校園招募及交流計劃如下，誠摯邀請貴校學生踴躍報名。 煩請協助轉發公告給同學知悉，歡迎來信洽談合作交流項目。謝謝！ Intel Taiwan Campus Program 時間 內容 報名網址 參加方式 Internship and College Graduate Hire 1. 實習與新鮮人招募 即日起報名至2022年6月 全年、暑期實習、新鮮人職缺及', 'payload': {'partId': '', 'mimeType': 'multipart/related', 'filename': '', 'headers': [{'name': 'Delivered-To', 'value': 'leo4707@gmail.com'}, {'name': 'Received', 'value': 'by 2002:adf:f94d:0:0:0:0:0 with SMTP id q13csp1056053wrr;        Sun, 6 Mar 2022 19:31:35 -0800 (PST)'}, {'name': 'X-Google-Smtp-Source', 'value': 'ABdhP
dmarc=pass (p=REJECT sp=REJECT dis=NONE) header.from=medium.com'}, {'name': 'Return-Path', 'value': '<bounces+1823144-cf73-leo4707=gmail.com@email.medium.com>'}, {'name': 'Received', 'value': 'from o25.email.medium.com (o25.email.medium.com. [149.72.177.236])        by mx.google.com with ESMTPS id t9-20020a170902e84900b00151eb057ddcsi1689521plg.290.2022.03.06.15.30.01        for <leo4707@gmail.com>        (version=TLS1_3 cipher=TLS_AES_128_GCM_SHA256 bits=128/128);        Sun, 06 Mar 2022 15:30:02 -0800 (PST)'}, {'name': 'Received-SPF', 'value': 'fail (google.com: domain of bounces+1823144-cf73-leo4707=gmail.com@email.medium.com does not designate 149.72.177.236 as permitted sender) client-ip=149.72.177.236;'}, {'name': 'Authentication-Results', 'value': 'mx.google.com;       dkim=pass header.i=@medium.com header.s=m1 header.b=JAyZEPye;       dkim=pass header.i=@sendgrid.info header.s=smtpapi header.b=M51ONmXv;       spf=fail (google.com: domain of bounces+1823144-cf73-leo4707=gmail.com@email.medium.com does not designate 149.72.177.236 as permitted sender) smtp.mailfrom="bounces+1823144-cf73-leo4707=gmail.com@email.medium.com";       dmarc=pass (p=REJECT sp=REJECT dis=NONE) header.from=medium.com'}, {'name': 'DKIM-Signature', 'value': 'v=1; a=rsa-sha256; c=relaxed/relaxed; d=medium.com; h=content-type:from:mime-version:subject:reply-to:list-unsubscribe: x-feedback-id:to; s=m1; bh=bax6HfVdCTjBClWwqOv ...
#   8%|███▍                                       | 8/100 [00:02<00:30,  3.02it/s]
# {'id': '17f6006e0c4b6800', 'threadId': '17f6006e0c4b6800', 'labelIds': ['UNREAD', 'CATEGORY_UPDATES', 'INBOX'], 'snippet': 'Put your crypto to work Try Binance Pro and access Binance Earn, the easiest and safest way to grow your crypto with zero risk. Learn more about Binance Pro Binance Pro offers the classic Binance app', 'payload': {'partId': '', 'mimeType': 'text/html', 'filename': '', 'headers': [{'name': 'Delivered-To', 'value': 'leo4707@gmail.com'}, {'name': 'Received', 'value': 'by 2002:adf:f94d:0:0:0:0:0 with SMTP id q13csp772420wrr;        Sun, 6 Mar 2022 08:18:58 -0800 (PST)'}, {'name': 'X-Google-Smtp-Source', 'value': 'ABdhPJzdezQf/4up1sftHNCzn0Kimd3Fhg5q03dqhvYht2q4PfIDWk93BdUdtV3f0VQhFA9Pn6Wb'}, {'name': 'X-Received', 'value': 'by 2002:aa7:9522:0:b0:4e1:d277:ce8 with SMTP id c2-20020aa79522000000b004e1d2770ce8mr8612262pfp.16.1646583537880;        Sun, 06 Mar 2022 08:18:57 -0800 (PST)'}, {'name': 'ARC-Seal', 'value': 'i=1; a=rsa-sha256; t=1646583537; cv=none;        d=google.com; s=arc-20160816;        b=fILClekmurHNWbWG27mu51LItdQxvRQb8Shmz5JkQyDWw2nE7oElnqtBaQS5kejovc         uHDOEvBhXkW3jjYzEt/wpAraj3fgFldhRQJHlm9kAqJXKHf2ah2AUJhJR5MZxoGPnJYY         7ceB3LrBljTdBbKH3G9HfsIaZhd2ysaKsOUG24bXH0S7FoCfLHbNphIuUUbrNB5dNv1G         L+q7LFkxvFadDUn+W+FkeaBcEH+mfbhJb6kmoOvvkrAk6x2PpVJ+ktNqanQY8IyA2+8o         jZkAdwsOsR+lRcsW+MNjyU6exi+OwMSYsgR6FnMKz6sT4Yt4IZixDNr5tRmgtUtL/KN3         Ty3A=='}, {'name': 'ARC-Message-Signature', 'value': 'i=1; a=rsa-sha256; c=relaxed/relaxed; d=google.com; s=arc-20160816;        h=content-transfer-encoding:mime-version:subject:message-id:to:from         :date:sender:dkim-signature:dkim-signature;        bh=EU1aS6McFtcE9Ns9Lqa5sW5Sq7l7LntBk0kEnf4s1+4=;        b=kBhFBP7lGNjNaOMIT/KjyP82kvL5kcGLTVrMj+Eacj+dLuPXXvzmDUJLI5cu0VFAWo         EpkPlYoIO/7v5hw2gn063gQqEe8V+ChV2QGHSjOlVEnIX4YpBDTh1XuujsWxKHk1gEI7         zZqEPDJE0ZrOdpwXZWAFYp+aiDfs/VYxvwyZFrTzmVuoImF8RVSWHskOvbGjTDLRcShP         f9IX7Er7U0STZcjceXwREbngtTkdwKmvoNRWoDZe/+9omZkI5jPkBlbl8xDCKTqKqU+t         QJTdtObdE/VDkek8NquahPFjokAFORUFazqvVMLv66VbT+p8MGA86j7xcx2zON6u43ey         D3NA=='}, {'name': 'ARC-Authentication-Results', 'value': 'i=1; mx.google.com;       dkim=pass header.i=@mgmailer.binance.com header.s=mx header.b=0SnzdPTc;       dkim=pass header.i=@mailgun.org header.s=mg header.b=TTgVzKLT;       spf=pass (google.com: domain of bounce+535a4d.a2d5e5-leo4707=gmail.com@mgmailer.binance.com designates 69.72.47.70 as permitted sender) smtp.mailfrom="bounce+535a4d.a2d5e5-leo4707=gmail.com@mgmailer.binance.com";       dmarc=pass (p=NONE sp=NONE dis=NONE) header.from=mgmailer.binance.com'}, {'name': 'Return-Path', 'value': '<bounce+535a4d.a2d5e5-leo4707=gmail.com@mgmailer.binance.com>'}, {'name': 'Received', 'value': 'from m47-70.mailgun.net (m47-70.mailgun.net. [69.72.47.70])        by mx.google.com with UTF8SMTPS id bd10-20020a656e0a000000b003471d131ef0si10543708pgb.34.2022.03.06.08.18.57        for <leo4707@gmail.com>        (version=TLS1_3 cipher=TLS_AES_128_GCM_SHA256 bits=128/128);        Sun, 06 Mar 2022 08:18:57 -0800 (PST)'}, {'name': 'Received-SPF', 'value': 'pass (google.com: domain of bounce+535a4d.a2d5e5-leo4707=gmail.com@mgmailer.binance.com designates 69.72.47.70 as permitted sender) client-ip=69.72.47.70;'}, {'name': 'Authentication-Results', 'value': 'mx.google.com;       dkim=pass header.i=@mgmailer.binance.com header.s=mx header.b=0SnzdPTc;       dkim=pass header.i=@mailgun.org header.s=mg header.b=TTgVzKLT;       spf=pass (google.com: domain of bounce+535a4d.a2d5e5-leo4707=gmail.com@mgmailer.binance.com designates 69.72.47.70 as permitted sender) smtp.mailfrom="bounce+535a4d.a2d5e5-leo4707=gmail.com@mgmailer.binance.com";       dmarc=pass (p=NONE sp=NONE dis=NONE) header.from=mgmailer.binance.com'}, {'name': 'DKIM-Signature', 'value': 'a=rsa-sha256; v=1; c=relaxed/relaxed; d=mgmailer.binance.com; q=dns/txt; s=mx; t=1646583537; h=Content-Transfer-Encoding: Content-Type: Mime-Version: Subject: Subject: Message ...
#   9%|███▊                                       | 9/100 [00:02<00:29,  3.11it/s]
# {'id': '17f600435f311d06', 'threadId': '17f600435f311d06', 'labelIds': ['UNREAD', 'CATEGORY_UPDATES', 'INBOX'], 'snippet': '親愛的客戶您好： 您於111年03月07日00時15分(網路帳號：身分證號L12521****)在本公司e動郵局登入成功。 提醒您，您可至本公司e動郵局設定登入email通知之發送條件，設定流程如下： 1. 登入e動郵局。 2. 點選「帳戶基本資料管理」＞「通知服務」＞「登入通知」，即可依「登入時間」或「當日登入次數」設定寄送條件。 本電子郵件係由系統自動發送，請勿直接回覆本郵件。 ※以上內容如有', 'payload': {'partId': '', 'mimeType': 'multipart/related', 'filename': '', 'headers': [{'name': 'Delivered-To', 'value': 'leo4707@gmail.com'}, {'name': 'Received', 'value': 'by 2002:adf:f94d:0:0:0:0:0 with SMTP id q13csp770765wrr;        Sun, 6 Mar 2022 08:16:03 -0800 (PST)'}, {'name': 'X-Google-Smtp-Source', 'value': 'ABdhP
='}, {'name': 'ARC-Authentication-Results', 'value': 'i=1; mx.google.com;       spf=pass (google.com: domain of mpost@mail.post.gov.tw designates 124.219.115.81 as permitted sender) smtp.mailfrom=mpost@mail.post.gov.tw'}, {'name': 'Return-Path', 'value': '<mpost@mail.post.gov.tw>'}, {'name': 'Received', 'value': 'from mail.post.gov.tw ([124.219.115.81])        by mx.google.com with ESMTPS id f17-20020a170902ce9100b0014ce46a4bd1si10407385plg.485.2022.03.06.08.15.51        for <leo4707@gmail.com>        (version=TLS1_2 cipher=ECDHE-ECDSA-AES128-GCM-SHA256 bits=128/128);        Sun, 06 Mar 2022 08:15:52 -0800 (PST)'}, {'name': 'Received-SPF', 'value': 'pass (google.com: domain of mpost@mail.post.gov.tw designates 124.219.115.81 as permitted sender) client-ip=124.219.115.81;'}, {'name': 'Authentication-Results', 'value': 'mx.google.com;       spf=pass (google.com: domain of mpost@mail.post.gov.tw designates 124.219.115.81 as permitted sender) smtp.mailfrom=mpost@mail.post.gov.tw'}, {'name': 'Received', 'value': 'from FPMTA01.post.gov.tw (FPMTA01.post.gov.tw [127.0.0.1]) by FPMTA01.post.gov.tw (Service) with ESMTP id 087A8C14B4F for <leo4707@gmail.com>; Mon,  7 Mar 2022 00:14:50 +0800 (CST)'}, {'name': 'Received', 'value': 'from TPE080303-00003.email.chpost.com.tw (unknown [172.17.3.5]) by FPMTA01.post.gov.tw (Service) with ESMTP id D06F4C14B61 for <leo4707@gmail.com>; Mon,  7 Mar 2022 00:14:49 +0800 (CST)'}, {'name': 'Received', 'value': 'from TPE130039-20029.email.chpost.com.tw (172.18.2.191) by TPE080303-00003.email.chpost.com.tw (172.17.3.5) with Microsoft SMTP Server (TLS) id 15.0.1497.28; Mon, 7 Mar 2022 00:15:12 +0800'}, {'name': 'Received', 'value': 'from TPE08020D-00022 (172.18.2.60) by TPE130039-20029.email.chpost.com.tw (172.18.2.191) with Microsoft SMTP Server (TLS) id 15.0.1497.28; Mon, 7 Mar 2022 00:15:48 +0800'}, {'name': 'Date', 'value': 'Mon, 7 Mar 2022 00:15:45 +0800'}, {'name': 'From', 'value': '" ...
#  11%|████▌                                     | 11/100 [00:03<00:28,  3.07it/s]
# {'id': '17f5f93e2bcb8121', 'threadId': '17f5f93e2bcb8121', 'labelIds': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'], 'snippet': '去逛逛 l 賣東西 l 我的拍賣 l 取消訂閱 關於露天 ‧ 客服中心 ‧ 常見問題 ‧ 交易安全 ‧ 會員合約 ‧ 隱私權聲明 ‧ eBay 跨國交易 露天市集國際資訊股份有限公司版權所有，轉載必究‧Copyright© PChome eBay Co., Ltd.', 'payload': {'partId': '', 'mimeType': 'text/html', 'filename': '', 'headers': [{'name': 'Delivered-To', 'value': 'leo4707@gmail.com'}, {'name': 'Received', 'value': 'by 2002:adf:f94d:0:0:0:0:0 with SMTP id q13csp708957wrr;        Sun, 6 Mar 2022 06:13:22 -0800 (PST)'}, {'name': 'X-Google-Smtp-Source', 'value': 'ABdhPJy+RmZOmeY1/DWOr7YQoFQoYNLOLUFCt+8VqltUcBGkdohdHemI+Az+X4k5KcA2/54jbJ6d'}, {'name': 'X-Received', 'value': 'by 2002:a63:3c48:0:b0:380:7ee:f092 with SMTP id i8-20020a633c48000000b0038007eef092mr4515874pgn.310.1646576001795;        Sun, 06 Mar 2022 06:13:21 -0800 (PST)'}, {'name': 'ARC-Seal', 'value': 'i=1; a=rsa-sha256; t=1
='}, {'name': 'ARC-Authentication-Results', 'value': 'i=1; mx.google.com;       dkim=pass header.i=@email.playstation.com header.s=200608 header.b=ucmK+n3M;       spf=pass (google.com: domain of bounce-19_html-575229198-446230-6151033-13022@bounce.email.playstation.com designates 13.111.27.215 as permitted sender) smtp.mailfrom=bounce-19_HTML-575229198-446230-6151033-13022@bounce.email.playstation.com;       dmarc=pass (p=REJECT sp=REJECT dis=NONE) header.from=email.playstation.com'}, {'name': 'Return-Path', 'value': '<bounce-19_HTML-575229198-446230-6151033-13022@bounce.email.playstation.com>'}, {'name': 'Received', 'value': 'from ea215.mta.exacttarget.com (mta22.playstationemail.com. [13.111.27.215])        by mx.google.com with ESMTPS id gw9-20020a0562140f0900b0043510744545si444383qvb.213.2022.03.03.02.07.47        for <leo4707@gmail.com>        (version=TLS1_2 cipher=ECDHE-ECDSA-AES128-GCM-SHA256 bits=128/128);        Thu, 03 Mar 2022 02:07:48 -0800 (PST)'}, {'name': 'Received-SPF', 'value': 'pass (google.com: domain of bounce-19_html-575229198-446230-6151033-13022@bounce.email.playstation.com designates 13.111.27.215 as permitted sender) client-ip=13.111.27.215;'}, {'name': 'Authentication-Results', 'value': 'mx.google.com;       dkim=pass header.i=@email.playstation.com header.s=200608 header.b=ucmK+n3M;       spf=pass (google.com: domain of bounce-19_html-5752 ...
#  45%|██████████████████▉                       | 45/100 [00:14<00:18,  3.02it/s]
# {'id': '17f4eb3b12d98762', 'threadId': '17f4eb3b12d98762', 'labelIds': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'], 'snippet': '5 new and 0 updated articles today Welcome to the CodeProject Daily Build Read online version Thursday, March 03, 2022 Headline article Fluent Interface Pattern in C# - With Inheritance Problem (6', 'payload': {'partId': '', 'mimeType': 'text/html', 'filename': '', 'headers': [{'name': 'Delivered-To', 'value': 'leo4707@gmail.com'}, {'name': 'Received', 'value': 'by 2002:adf:f94d:0:0:0:0:0 with SMTP id q13csp731460wrr;        Wed, 2 Mar 2022 23:34:33 -0800 (PST)'}, {'name': 'X-Google-Smtp-Source', 'value': 'ABdhPJwQl+P+Wals3foXyr3WFlvpVNvYpxlvdWjlRB2yvTuebyljB46S1YPL2/HrxAkUykSkmPxt'}, {'name': 'X-Received', 'value': 'by 2002:a05:620a:35c:b0:648:e0da:8a64 with SMTP id t28-20020a05620a035c00b00648e0da8a64mr17880953qkm.73.1646292873575;        Wed, 02 Mar 2022 23:34:33 -0800 (PST)'}, {'name': 'ARC-Seal', 'value': 'i=1; a=rsa-sha256; t=1646292873; cv=none;        d=google.com; s=arc-20160816;        b=EHsd6yTIx+LUEkhKjsiknIPlE8Q9l8bMQk8KVoROtyYX+HAiGLN/aHLEJ9CXrwk3Xi         mkj0ZG7VW+slpWDMeThTufmpMU3Ju4C5965p4ezF+GxipGHXKrIqtW6UcP9n+eWpvCwW         2CAEx8+3UpgwrLT18+U5E6heQTu4TCo70JA74k+g86XIj3hos+Eo6D98BuHOazEaGL0f         05G5Ii5ULr7gloZ4MfZ0UTXN6NOth3Y8QTBoYAWVA8XgMP1tjxgarxaRHojedpy+QCgg         Xv5kX6CoKcX/AF0leAXyJRNSjTF88mc3ep4t1ERSmEm90q6bFio8ceTSIKpeUxKV5uqU         Vuig=='}, {'name': 'ARC-Message-Signature', 'value': 'i=1; a=rsa-sha256; c=relaxed/relaxed; d=google.com; s=arc-20160816;        h=message-id:content-transfer-encoding:subject:date:to:from         :mime-version:feedback-id:dkim-signature;        bh=zo3ULEu2HOUtFEHUCx+jOzqIRfBpZVH9P8KDntfbQjI=;        b=wnA/MeCFbdlgjnzJ8QJtRvIwP6nT1hQFDaRhRsilkWJ2D3u5NEoWO/yuSGaJPoJbpd         lVaHCCKnMQnw7SO+PJpW22ODSJ70aALwDylbPVjlrMY9qfSDpKTVtkBGqIv6qW/CKJnL         0kA3t85wf/AGlRLNT/T1kKHo6woFGXkyAL+VbOCUmq7JefTyPgnoJQfvVmKLdOO/smMg         XpdHo8LPf+He/hp8aZyxssO8NYr/otXPAG9ilxw38oaEfe+69j/9baAmChR3t4g0d4lQ         AkLaIKzsN2BtlGm8uapAAThoTyWXZFembku0eJN8w85hYFb467umz6TQ0WQrT4U23kxn         QBXw=='}, {'name': 'ARC-Authentication-Results', 'value': 'i=1; mx.google.com;       dkim=pass header.i=@maillist.codeproject.com header.s=mail header.b=XIt3IaMj;       spf=pass (google.com: domain of mailout@maillist.codeproject.com designates 76.74.234.204 as permitted sender) smtp.mailfrom=mailout@maillist.codeproject.com;       dmarc=pass (p=QUARANTINE sp=QUARANTINE dis=NONE) header.from=codeproject.com'}, {'name': 'Return-Path', 'value': '<mailout@maillist.codeproject.com>'}, {'name': 'Received', 'value': 'from mail.maillist.codeproject.com (mail.maillist.codeproject.com. [76.74.234.204])        by mx.google.com with ESMTP id p15-20020a0cc3cf000000b0043517839bbasi308777qvi.35.2022.03.02.23.34.33        for <leo4707@gmail.com>;        Wed, 02 Mar 2022 23:34:33 -0800 (PST)'}, {'name': 'Received-SPF', 'value': 'pass (google.com: domain of mailout@maillist.codeproject.com designates 76.74.234.204 as permitted sender) client-ip=76.74.234.204;'}, {'name': 'Authentication-Results', 'value': 'mx.google.com;       dkim=pass header.i=@maillist.codeproject.com header.s=mail header.b=XIt3IaMj;       spf=pass (google.com: domain of mailout@maillist.codeproject.com designates 76.74.234.204 as permitted sender) smtp.mailfrom=mailout@maillist.codeproject.com;       dmarc=pass (p=QUARANTINE sp=QUARANTINE dis=NONE) header.from=codeproject.com'}, {'name': 'Received', 'value': 'from jobs01 (unknown [192.168.5.180]) by mail.maillist.codeproject.com (Postfix) with ESMTP id A421C16A190 for <leo4707@gmail.com>; Thu,  3 Mar 2022 00:50:01 -0500 (EST)'}, {'name': 'DKIM-Signature', 'value': 'v=1; a=rsa-sha256; c=simple/simple; d=maillist.codeproject.com; s=mail; t=1646286601; bh=zo3ULEu2HOUtFEHUCx+jOzqIRfBpZVH9P8KDntfbQjI=; h=MIME-Version:From:To:Date:Subject:Content-Type:\t Content-Transfer-Encoding:Message-Id; b=XIt3IaMjD/f6tuZawQdEgbnjm5MnQKnX9Y28HnsbnQ4zAD9Xjh0hk01vLC5VNbY8A\t 8 ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <module>
# ----> 1 getEmails()
#
# Input In [5], in getEmails()
#      36 # messages is a list of dictionaries where each dictionary contains a message id.
#      37
#      38 # iterate through all the messages
#      39 for i in trange(len(messages)):
#      40     # Get the message from its id
# ---> 41     txt = service.users().messages().get(userId = 'me', id = messages[i]['id']).execute()
#      42     print(txt)
#      44     # Use try-except to avoid any Errors
#
# File ~/.local/lib/python3.8/site-packages/googleapiclient/_helpers.py:131, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     130         logger.warning(message)
# --> 131 return wrapped(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/googleapiclient/http.py:922, in HttpRequest.execute(self, http, num_retries)
#     919     self.headers["content-length"] = str(len(self.body))
#     921 # Handle retries for server-side errors.
# --> 922 resp, content = _retry_request(
#     923     http,
#     924     num_retries,
#     925     "request",
#     926     self._sleep,
#     927     self._rand,
#     928     str(self.uri),
#     929     method=str(self.method),
#     930     body=self.body,
#     931     headers=self.headers,
#     932 )
#     934 for callback in self.response_callbacks:
#     935     callback(resp)
#
# File ~/.local/lib/python3.8/site-packages/googleapiclient/http.py:190, in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     188 try:
#     189     exception = None
# --> 190     resp, content = http.request(uri, method, *args, **kwargs)
#     191 # Retry on SSL errors and socket timeout errors.
#     192 except _ssl_SSLError as ssl_error:
#
# File ~/.local/lib/python3.8/site-packages/google_auth_httplib2.py:218, in AuthorizedHttp.request(self, uri, method, body, headers, redirections, connection_type, **kwargs)
#     215     body_stream_position = body.tell()
#     217 # Make the request.
# --> 218 response, content = self.http.request(
#     219     uri,
#     220     method,
#     221     body=body,
#     222     headers=request_headers,
#     223     redirections=redirections,
#     224     connection_type=connection_type,
#     225     **kwargs
#     226 )
#     228 # If the response indicated that the credentials needed to be
#     229 # refreshed, then refresh the credentials and re-attempt the
#     230 # request.
#     231 # A stored token may expire between the time it is retrieved and
#     232 # the time the request is made, so we may need to try twice.
#     233 if (
#     234     response.status in self._refresh_status_codes
#     235     and _credential_refresh_attempt < self._max_refresh_attempts
#     236 ):
#
# File ~/.local/lib/python3.8/site-packages/httplib2/__init__.py:1701, in Http.request(self, uri, method, body, headers, redirections, connection_type)
#    1699             content = b""
#    1700         else:
# -> 1701             (response, content) = self._request(
#    1702                 conn, authority, uri, request_uri, method, body, headers, redirections, cachekey,
#    1703             )
#    1704 except Exception as e:
#    1705     is_timeout = isinstance(e, socket.timeout)
#
# File ~/.local/lib/python3.8/site-packages/httplib2/__init__.py:1421, in Http._request(self, conn, host, absolute_uri, request_uri, method, body, headers, redirections, cachekey)
#    1418 if auth:
#    1419     auth.request(method, request_uri, headers, body)
# -> 1421 (response, content) = self._conn_request(conn, request_uri, method, body, headers)
#    1423 if auth:
#    1424     if auth.response(response, body):
#
# File ~/.local/lib/python3.8/site-packages/httplib2/__init__.py:1373, in Http._conn_request(self, conn, request_uri, method, body, headers)
#    1371     pass
#    1372 try:
# -> 1373     response = conn.getresponse()
#    1374 except (http.client.BadStatusLine, http.client.ResponseNotReady):
#    1375     # If we get a BadStatusLine on the first try then that means
#    1376     # the connection just went stale, so retry regardless of the
#    1377     # number of RETRIES set.
#    1378     if not seen_bad_status_line and i == 1:
#
# File /usr/lib/python3.8/http/client.py:1348, in HTTPConnection.getresponse(self)
#    1346 try:
#    1347     try:
# -> 1348         response.begin()
#    1349     except ConnectionError:
#    1350         self.close()
#
# File /usr/lib/python3.8/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File /usr/lib/python3.8/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File /usr/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File /usr/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:
